# %% [markdown]
# <a href="https://colab.research.google.com/github/DanishCH/Mastering_Pandas/blob/main/Pandas_Subset_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Select a subset of a DataFrame**

# %%
# import seaborn as sns
import pandas as pd
titanic = pd.read_csv("/content/Titanic-Dataset.csv")
# # Load the Titanic dataset directly as a DataFrame
# titanic = sns.load_dataset('titanic')
# #Store As CSV
# titanic.to_csv("titanic.csv", index=False)

titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#interested in the age of the Titanic passengers
ages = titanic["Age"]
print(ages)
#Selecting first 10 rows
ages.head(10)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %% [markdown]
# To select a single column, use square brackets [] with the column name of the column of interest.

# %% [markdown]
# Each column in a DataFrame is a Series. As a single column is selected, the returned object is a pandas Series. We can verify this by checking the type of the output:

# %%
type(titanic["Age"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **the shape of the output**

# %%
titanic["Age"].shape #891 rows as output shown
# Out:
# (891,)

# %% [markdown]
# DataFrame.shape is an attribute of a pandas Series and DataFrame containing the number of rows and columns: (nrows, ncolumns). A pandas Series is 1-dimensional and only the number of rows is returned.

# %% [markdown]
# **age and sex of the Titanic passengers.**

# %%
age_sex = titanic[["Age","Sex"]]
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %% [markdown]
# To select multiple columns, use a list of column names within the selection brackets [].

# %%
#data type
type(age_sex)
# Out:
# pandas.core.frame.DataFrame

# %%
age_sex.shape # or titanic[["age","shape"]]
# Out:
# (891, 2)

# %% [markdown]
# **filter specific rows from a DataFrame**

# %% [markdown]
# passengers older than 30 years.

# %%
#To select rows based on a conditional expression, use a condition inside the selection brackets [].
passenger_above_30 =titanic[titanic["Age"]>30]
passenger_above_30
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# The condition inside the selection brackets titanic["Age"] > 35 checks for which rows the Age column has a value larger than 35:

# %%
titanic["Age"]>35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# The output of the conditional expression (>, but also ==, !=, <, <=,… would work) is actually a pandas Series of boolean values (either True or False) with the same number of rows as the original DataFrame.
#
#  Such a Series of boolean values can be used to filter the DataFrame by putting it in between the selection brackets [].
#
#  Only rows for which the value is True will be selected.
#
# We know from before that the original Titanic DataFrame consists of 891 rows. Let’s have a look at the number of rows which satisfy the condition by checking the shape attribute of the resulting DataFrame above_35:

# %% [markdown]
# **Titanic passengers from cabin class 2 and 3.**

# %%
cabin_2_3 = titanic[titanic["Pclass"].isin([2,3])]
cabin_2_3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
# titanic[(titanic["Pclass"] == 2) | (titanic["Pclass"] == 3)]

# %% [markdown]
# When combining multiple conditional statements, each condition must be surrounded by parentheses (). Moreover, you can not use or/and but need to use the or operator | and the and operator &.

# %%
female_cabin_2_3 = cabin_2_3[cabin_2_3['Sex'] == 'female']
female_cabin_2_3
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **data for which the age is known.**

# %%
female_nonull_age=female_cabin_2_3[female_cabin_2_3['Age'].notna()]
female_nonull_age
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **data for which the age is not known.**

# %%
female_null_age=female_cabin_2_3[female_cabin_2_3['Age'].isna()]
female_null_age
# Out:
#      PassengerId  Survived  Pclass  \
# 19            20         1       3
# 28            29         1       3
# 32            33         1       3
# 47            48         1       3
# 82            83         1       3
# 109          110         1       3
# 128          129         1       3
# 140          141         0       3
# 180          181         0       3
# 186          187         1       3
# 198          199         1       3
# 229          230         0       3
# 235          236         0       3
# 240          241         0       3
# 241          242         1       3
# 264          265         0       3
# 274          275         1       3
# 300          301         1       3
# 303          304         1       2
# 330          331         1       3
# 347          348         1       3
# 358          359         1       3
# 359          360         1       3
# 367          368         1       3
# 368          369         1       3
# ...

# %% [markdown]
# **Names of the passengers younger than 35 years.**

# %%
younger_passenger = titanic[titanic["Age"]<35]
younger_passenger
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **names of the female passengers older than 35 years.**

# %%
older_female_passenger = female_nonull_age.loc[female_nonull_age['Age'] > 35, "Name"]
older_female_passenger
# Out:
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 25     Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 40        Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# 132       Robins, Mrs. Alexander A (Grace Charity Laury)
# 161    Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...
# 167      Skoog, Mrs. William (Anna Bernhardina Karlsson)
# 254             Rosblom, Mrs. Viktor (Helena Wilhelmina)
# 259                          Parrish, Mrs. (Lutie Davis)
# 272            Mellinger, Mrs. (Elizabeth Anne Maidment)
# 276                    Lindblom, Miss. Augusta Charlotta
# 327                              Ball, Mrs. (Ada E Hall)
# 346                            Smith, Miss. Marion Elsie
# 357                            Funk, Miss. Annie Clemmer
# 362                      Barbara, Mrs. (Catherine David)
# 387                                     Buss, Miss. Kate
# 432    Louch, Mrs. Charles Alexander (Alice Adelaide ...
# ...

# %% [markdown]
# In this case, a subset of both rows and columns is made in one go and just using selection brackets [] is not sufficient anymore.
#
# The loc/iloc operators are required in front of the selection brackets [].
#
#  When using loc/iloc, the part before the comma is the rows you want, and the part after the comma is the columns you want to select.

# %% [markdown]
# **rows 10 till 25 and columns 3 to 5**

# %%
female_nonull_age.iloc[10:26, 3:6]
# Out:
#                                                  Name     Sex   Age
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0
# 44                      Devaney, Miss. Margaret Delia  female  19.0
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0
# 56                                  Rugg, Miss. Emily  female  21.0
# 58                       West, Miss. Constance Mirium  female   5.0
# 66                       Nye, Mrs. (Elizabeth Ramell)  female  29.0
# 68                    Andersson, Miss. Erna Alexandra  female  17.0
# 71                         Goodwin, Miss. Lillian Amy  female  16.0
# ...

# %% [markdown]
# **New Value Assigned**

# %%
female_nonull_age.iloc[:3,3]="DD"
female_nonull_age.iloc[:5,3]
# Out:
# 2                                       DD
# 8                                       DD
# 9                                       DD
# 10         Sandstrom, Miss. Marguerite Rut
# 14    Vestrom, Miss. Hulda Amanda Adolfina
# Name: Name, dtype: object

# %% [markdown]
# # **REMEMBER**
# When selecting subsets of data, square brackets [] are used.
#
# Inside these square brackets, you can use a single column/row label, a list of column/row labels, a slice of labels, a conditional expression or a colon.
#
# Use loc for label-based selection (using row/column names).
#
# Use iloc for position-based selection (using table positions).
#
# You can assign new values to a selection based on loc/iloc
