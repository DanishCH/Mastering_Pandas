# %% [markdown]
# <a href="https://colab.research.google.com/github/DanishCH/Mastering_Pandas/blob/main/Pandas_Subset_Selection02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Copied Data From Clipboard**

# %%
import seaborn as sns
import pandas as pd

# %%
df_titanic = sns.load_dataset('titanic')
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic.to_csv("kashti.csv")

# %%
try:
    df_california_house = pd.read_clipboard()
    if df_california_house.empty:
        print("Warning: Clipboard is empty or contains no parsable data. df_california_house is an empty DataFrame.")
except Exception as e:
    print(f"Error reading clipboard: {e}")
    df_california_house = pd.DataFrame() # Define it as an empty DataFrame to avoid NameError
df_california_house
# Out:
# Error reading clipboard:
#     Pyperclip could not find a copy/paste mechanism for your system.
#     For more information, please visit
#     https://pyperclip.readthedocs.io/en/latest/index.html#not-implemented-error
# Empty DataFrame
# Columns: []
# Index: []

# %%
len(df_titanic)
# Out:
# 891

# %%
print(f"Loaded dataset {df_titanic.shape[0]} rows, {df_titanic.shape[1]} columns")
# Out:
# Loaded dataset 891 rows, 15 columns

# %%
# import numpy as np
# from sklearn.model_selection import train_test_split

# # --- Sequential Split ---
# # Calculate the midpoint for splitting
# midpoint = len(df_titanic) // 2

# # Split into two sequential DataFrames
# df_titanic_seq1 = df_titanic.iloc[:midpoint]
# df_titanic_seq2 = df_titanic.iloc[midpoint:]

# print("Sequential Split:")
# print(f"df_titanic_seq1 shape: {df_titanic_seq1.shape}")
# print(f"df_titanic_seq2 shape: {df_titanic_seq2.shape}")
# print("\n")

# # --- Random Split ---
# # Split into two random DataFrames (50/50 split)
# # Using random_state for reproducibility
# df_titanic_rand1, df_titanic_rand2 = train_test_split(df_titanic, test_size=0.5, random_state=42)

# print("Random Split:")
# print(f"df_titanic_rand1 shape: {df_titanic_rand1.shape}")
# print(f"df_titanic_rand2 shape: {df_titanic_rand2.shape}")

# %%
midpoint = df_titanic.shape[0] // 2
midpoint
# import numpy as np
df_titanic_seq1 = df_titanic.iloc[:445]
df_titanic_seq1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 440         1       2  female  45.0      1      1  26.2500        S  Second
# 441         0       3    male  20.0      0      0   9.5000        S   Third
# 442         0       3    male  25.0      1      0   7.7750        S   Third
# 443         1       2  female  28.0      0      0  13.0000        S  Second
# 444         1       3    male   NaN      0      0   8.1125        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic_seq2 = df_titanic.iloc[445:]
df_titanic_seq2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 445         1       1    male   4.0      0      2  81.8583        S   First
# 446         1       2  female  13.0      0      1  19.5000        S  Second
# 447         1       1    male  34.0      0      0  26.5500        S   First
# 448         1       3  female   5.0      2      1  19.2583        C   Third
# 449         1       1    male  52.0      0      0  30.5000        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import random

# %%
# second way to split data with randomness
df_titanic_train = df_titanic.sample(frac=0.7, random_state=1)
df_titanic_train
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 675         0       3    male  18.0      0      0   7.7750        S   Third
# 240         0       3  female   NaN      1      0  14.4542        C   Third
# 230         1       1  female  35.0      1      0  83.4750        S   First
# 326         0       3    male  61.0      0      0   6.2375        S   Third
# 458         1       2  female  50.0      0      0  10.5000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df_titanic_test = df_titanic.drop(df_titanic_train.index)
df_titanic_test
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# 21          1       2    male  34.0      0      0  13.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 872         0       1    male  33.0      0      0   5.0000        S   First
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#combined both seprate data set in on frame
combined_titanic = pd.concat([df_titanic_train, df_titanic_test]).reset_index(drop=True)
combined_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           1       1  female  48.0      0      0  25.9292        S   First
# 1           0       3    male   NaN      0      0   7.8958        S   Third
# 2           1       2  female  17.0      0      0  10.5000        S  Second
# 3           0       3  female   NaN      0      0   8.1375        Q   Third
# 4           1       2  female   7.0      0      2  26.2500        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       1    male  33.0      0      0   5.0000        S   First
# 887         1       1  female  56.0      0      1  83.1583        C   First
# 888         1       2  female  25.0      0      1  26.0000        S  Second
# 889         0       2    male  27.0      0      0  13.0000        S  Second
# 890         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
combined_titanic_reset = combined_titanic.reset_index(drop=True)
display(combined_titanic_reset.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         1       1  female  48.0      0      0  25.9292        S   First
# 1         0       3    male   NaN      0      0   7.8958        S   Third
# 2         1       2  female  17.0      0      0  10.5000        S  Second
# 3         0       3  female   NaN      0      0   8.1375        Q   Third
# 4         1       2  female   7.0      0      2  26.2500        S  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0  woman       False    D  Southampton   yes   True
# 1    man        True  NaN  Southampton    no   True
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False  NaN   Queenstown    no   True
# 4  child       False  NaN  Southampton   yes  False

# %%
#how many variable or types in the class column
combined_titanic['class'].unique()
# Out:
# ['First', 'Third', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
#every types how many time in the  column
combined_titanic['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
# i want to see the data of passenger which are reserved first class
first_class_passengers = combined_titanic[combined_titanic["class"] == "First"]

# %%
#if i want to see data of male belongs to Queensland and their age is less then 30
df_titanic[(df_titanic.sex == "male") & (df_titanic.age < 30) & (df_titanic.embark_town == "Queenstown")]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  \
# 16          0       3  male   2.0      4      1  29.1250        Q  Third
# 143         0       3  male  19.0      0      0   6.7500        Q  Third
# 171         0       3  male   4.0      4      1  29.1250        Q  Third
# 278         0       3  male   7.0      4      1  29.1250        Q  Third
# 421         0       3  male  21.0      0      0   7.7333        Q  Third
# 510         1       3  male  29.0      0      0   7.7500        Q  Third
# 703         0       3  male  25.0      0      0   7.7417        Q  Third
# 787         0       3  male   8.0      4      1  29.1250        Q  Third
#
#        who  adult_male deck embark_town alive  alone
# 16   child       False  NaN  Queenstown    no  False
# 143    man        True  NaN  Queenstown    no   True
# 171  child       False  NaN  Queenstown    no  False
# 278  child       False  NaN  Queenstown    no  False
# ...
